# %%
# !pip install -q PyPDF2 pdfplumber

# %%
# !wget https://raw.githubusercontent.com/liang799/MehScrapper/main/questionPool.pdf -O questionPool.pdf
# Out:
# --2022-07-29 11:17:24--  https://raw.githubusercontent.com/liang799/MehScrapper/main/questionPool.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 890809 (870K) [application/octet-stream]
# Saving to: ‘questionPool.pdf’
#
# questionPool.pdf    100%[===================>] 869.93K  --.-KB/s    in 0.05s
#
# 2022-07-29 11:17:24 (18.3 MB/s) - ‘questionPool.pdf’ saved [890809/890809]

# %% [markdown]
# ## PDF to .txt

# %%
from PyPDF2 import PdfReader

reader = PdfReader("questionPool.pdf")

text = ""  
for page in reader.pages:
    text += page.extractText() + "\n"

f = open("demofile2.txt", "w")
f.write(text)
f.close()
# !tail -n 25 demofile2.txt
# Out:
# b. False
#
# 348.  Among the machine learning algorithms, which of the following is not an integrated
# learning strategy?
# a. Boosting
# b. Stacking
# c. Bagging
# d. Marking
#
# 349.  AI Chips used in business applications can be classified as
# a. training
# b. GPU
# c. Model building
# d. Reasoning

# %% [markdown]
# ### Format demofile2.txt

# %%
import re

read = open("demofile2.txt", "r")
result = open("format.txt", "w")

question = ""
hasQuestion = False
for line in read:
  line = line.strip()
  hasDigit = line[:1].isdigit()
  option = re.findall("^[a-f]\. (\w.+)", line)
 
  if hasDigit:
    question = line
    hasQuestion = True
  elif len(line) != 0:
    if not option:
      question += " " + line
    else:
      if hasQuestion:
        result.write("\n" + question + "\n")
        hasQuestion = False
      result.write(line + "\n")

result.close()
read.close()

# !tail format.txt
# Out:
# a. Boosting
# b. Stacking
# c. Bagging
# d. Marking
#
# 349.  AI Chips used in business applications can be classified as
# a. training
# b. GPU
# c. Model building
# d. Reasoning

# %% [markdown]
# ### Get Answers

# %%
import pdfplumber
f = open("answers.txt", "w")
with pdfplumber.open('questionPool.pdf') as pdf: 
    for page in pdf.pages:
        try:
            clean_text = page.filter(lambda obj: obj["object_type"] == "char" and "Bold" in obj["fontname"])
            f.write(clean_text.extract_text())
        except IndexError:
            print("")
            break
f.close()
# !head answers.txt
# Out:
# b.  False
#
# a.  Action
# b.  Perception
# c.  Cognition
# a.  7X24
# c.  hyperplane
# b.  Find the average
# c.  Voting system
# a.  Artificial Intelligence

# %%
import os

f = open("answers.txt", "r")
edited = open("answers.md", "w")
answers = []

for line in f:
  if len(line.strip()) != 0:
    edited.write(line.strip() + "\n")
    answers.append(line.strip())

os.remove("answers.txt") 
# !head answers.md
# Out:
# b.  False
# a.  Action
# b.  Perception
# c.  Cognition
# a.  7X24
# c.  hyperplane
# b.  Find the average
# c.  Voting system
# a.  Artificial Intelligence
# b.  Web development

# %% [markdown]
# ## TXT to CSV

# %% [markdown]
# ### CSV v1

# %%
import re
mcqs = open("demofile2.txt", "r")

csv = open("results.csv", "w")
csv.write("No,Question,Answer1,AnswerCorrect1,Answer2,AnswerCorrect2,Answer3,AnswerCorrect3,Answer4,AnswerCorrect4,Answer5,AnswerCorrect5,Answer6,AnswerCorrect6,Answer7,AnswerCorrect7,Answer8,AnswerCorrect8,Answer9,AnswerCorrect9,Answer10,AnswerCorrect10,Hint,Explanation,Category\n")

string = ""
for line in mcqs:
  line = line.strip()
  hasDigit = line[:1].isdigit()
  option = re.findall("^[a-f]\. (\w.+)", line)

  if hasDigit:
    quesPos = line.find(".")
    string += line[:quesPos] + ","
    string += "\"" + line[quesPos+2:] + "\""
  elif option:
    string += "," + option[0] + ","
  elif len(line) != 0:
    string += "\"" + line + "\""
  else:
    csv.write(string + "\n")
    string = ""

csv.close()

# %%
import pandas as pd

df = pd.read_csv('results.csv')
df
# Out:
#       No                                           Question  \
# 0      1  TensorF low Operations and Computation Graph a...
# 1      2  What are the categories of artificial intellig...
# 2      3  Traffic agent can a chieve ______ hour full ti...
# 3      4  The pe rceptron can be displayed in space as _...
# 4      5  In Random Forest algorithm, what st rategy is ...
# ..   ...                                                ...
# 346  345   CPUs improve AI performance  mainly through i...
# 347  346   The time interv al in the Python language is ...
# 348  347   Self -encoder is an unsupervised learning alg...
# 349  348   Among the machine learning algorithms, which ...
# 350  349   AI Chips used in business applications can be...
#
#                Answer1 AnswerCorrect1           Answer2 AnswerCorrect2  \
# 0                 True              1             False              1
# 1               Action            NaN        Perception            NaN
# 2                 7X24            NaN              5X24            NaN
# 3                 line            NaN              flat            NaN
# 4    Cumulative system            NaN  Find the average            NaN
# ..                 ...            ...               ...            ...
# 346               TRUE              1             FALSE              1
# 347               True   1"b.  False"               NaN            NaN
# 348               True              1             False              1
# 349           Boosting            NaN          Stacking            NaN
# 350           training            NaN               GPU            NaN
#
#             Answer3 AnswerCorrect3            Answer4 AnswerCorrect4  ...  \
# 0               NaN            NaN                NaN            NaN  ...
# 1         Cognition            NaN  None of the above            NaN  ...
# 2              5X12            NaN               7X12            NaN  ...
# 3        hyperplane            NaN              point            NaN  ...
# 4     Voting system            NaN       Find the max            NaN  ...
# ..              ...            ...                ...            ...  ...
# 346             NaN            NaN                NaN            NaN  ...
# 347             NaN            NaN                NaN            NaN  ...
# 348             NaN            NaN                NaN            NaN  ...
# 349         Bagging            NaN            Marking            NaN  ...
# 350  Model building            NaN          Reasoning            NaN  ...
#
#     AnswerCorrect7 Answer8 AnswerCorrect8 Answer9  AnswerCorrect9  Answer10  \
# 0              NaN     NaN            NaN     NaN             NaN       NaN
# 1              NaN     NaN            NaN     NaN             NaN       NaN
# 2              NaN     NaN            NaN     NaN             NaN       NaN
# 3              NaN     NaN            NaN     NaN             NaN       NaN
# 4              NaN     NaN            NaN     NaN             NaN       NaN
# ..             ...     ...            ...     ...             ...       ...
# 346            NaN     NaN            NaN     NaN             NaN       NaN
# 347            NaN     NaN            NaN     NaN             NaN       NaN
# 348            NaN     NaN            NaN     NaN             NaN       NaN
# 349            NaN     NaN            NaN     NaN             NaN       NaN
# 350            NaN     NaN            NaN     NaN             NaN       NaN
#
#      AnswerCorrect10  Hint  Explanation  Category
# 0                NaN   NaN          NaN       NaN
# 1                NaN   NaN          NaN       NaN
# 2                NaN   NaN          NaN       NaN
# 3                NaN   NaN          NaN       NaN
# 4                NaN   NaN          NaN       NaN
# ..               ...   ...          ...       ...
# 346              NaN   NaN          NaN       NaN
# 347              NaN   NaN          NaN       NaN
# 348              NaN   NaN          NaN       NaN
# 349              NaN   NaN          NaN       NaN
# 350              NaN   NaN          NaN       NaN
#
# [351 rows x 25 columns]

# %% [markdown]
# ### CSV V2

# %%
import re
mcqs = open("format.txt", "r")

csv = open("format.csv", "w")
csv.write("No,Question,Answer1,AnswerCorrect1,Answer2,AnswerCorrect2,Answer3,AnswerCorrect3,Answer4,AnswerCorrect4,Answer5,AnswerCorrect5,Answer6,AnswerCorrect6,Answer7,AnswerCorrect7,Answer8,AnswerCorrect8,Answer9,AnswerCorrect9,Answer10,AnswerCorrect10,Hint,Explanation,Category\n")

string = ""
for line in mcqs:
  line = line.strip()
  hasDigit = line[:1].isdigit()
  option = re.findall("^[a-f]\. (\w.+)", line)

  if hasDigit:
    quesPos = line.find(".")
    string += line[:quesPos] + ","
    string += "\"" + line[quesPos+2:] + "\""
  elif option:
      string += "," + option[0] + ","
  else:
    csv.write(string + "\n")
    string = ""

csv.close()

# %%
csv = open("format.csv", "r")
formatted = open("results.csv", "w")

for line in csv:
  if len(line.strip()) != 0:
    formatted.write(line)
  else:
    print("Miss!")
# Out:
# Miss!

# %%
import pandas as pd

df = pd.read_csv('results.csv')
df
# Out:
#       No                                           Question  \
# 0      1  TensorF low Operations and Computation Graph a...
# 1      2  What are the categories of artificial intellig...
# 2      3  Traffic agent can a chieve ______ hour full ti...
# 3      4  The pe rceptron can be displayed in space as _...
# 4      5  In Random Forest algorithm, what st rategy is ...
# ..   ...                                                ...
# 307  344   What  are the results returned by if conditio...
# 308  345   CPUs improve AI performance  mainly through i...
# 309  346   The time interv al in the Python language is ...
# 310  347   Self -encoder is an unsupervised learning alg...
# 311  348   Among the machine learning algorithms, which ...
#
#                Answer1 AnswerCorrect1           Answer2 AnswerCorrect2  \
# 0                 True            NaN             False            NaN
# 1               Action            NaN        Perception            NaN
# 2                 7X24            NaN              5X24            NaN
# 3                 line            NaN              flat            NaN
# 4    Cumulative system            NaN  Find the average            NaN
# ..                 ...            ...               ...            ...
# 307               True              1               NaN          FALSE
# 308               TRUE              1               NaN          FALSE
# 309               True              1               NaN            NaN
# 310               True              1               NaN          False
# 311           Boosting            NaN          Stacking            NaN
#
#            Answer3 AnswerCorrect3            Answer4 AnswerCorrect4  ...  \
# 0              NaN            NaN                NaN            NaN  ...
# 1        Cognition            NaN  None of the above            NaN  ...
# 2             5X12            NaN               7X12            NaN  ...
# 3       hyperplane            NaN              point            NaN  ...
# 4    Voting system            NaN       Find the max            NaN  ...
# ..             ...            ...                ...            ...  ...
# 307            NaN           Null                NaN            NaN  ...
# 308              1            NaN                NaN            NaN  ...
# 309            NaN            NaN                NaN            NaN  ...
# 310              1            NaN                NaN            NaN  ...
# 311        Bagging            NaN            Marking            NaN  ...
#
#     AnswerCorrect7 Answer8 AnswerCorrect8  Answer9  AnswerCorrect9  Answer10  \
# 0              NaN     NaN            NaN      NaN             NaN       NaN
# 1              NaN     NaN            NaN      NaN             NaN       NaN
# 2              NaN     NaN            NaN      NaN             NaN       NaN
# 3              NaN     NaN            NaN      NaN             NaN       NaN
# 4              NaN     NaN            NaN      NaN             NaN       NaN
# ..             ...     ...            ...      ...             ...       ...
# 307            NaN     NaN            NaN      NaN             NaN       NaN
# 308            NaN     NaN            NaN      NaN             NaN       NaN
# 309            NaN     NaN            NaN      NaN             NaN       NaN
# 310            NaN     NaN            NaN      NaN             NaN       NaN
# 311            NaN     NaN            NaN      NaN             NaN       NaN
#
#      AnswerCorrect10  Hint  Explanation  Category
# 0                NaN   NaN          NaN       NaN
# 1                NaN   NaN          NaN       NaN
# 2                NaN   NaN          NaN       NaN
# 3                NaN   NaN          NaN       NaN
# 4                NaN   NaN          NaN       NaN
# ..               ...   ...          ...       ...
# 307              NaN   NaN          NaN       NaN
# 308              NaN   NaN          NaN       NaN
# 309              NaN   NaN          NaN       NaN
# 310              NaN   NaN          NaN       NaN
# 311              NaN   NaN          NaN       NaN
#
# [312 rows x 25 columns]

# %%
csv = open("results.csv", "r")
int i = 0;
for line in csv:
  if (i)
# Out:
# b.  False
# a.  Action
# b.  Perception
# c.  Cognition
# a.  7X24
# c.  hyperplane
# b.  Find the average
# c.  Voting system
# a.  Artificial Intelligence
# b.  Web development
# c.  Game development
# b.  Fully Connected Layer
# c.  Convolutional Layer
# d.  Pooling Layer
# b.  False
# c.  create
# b.  Artificial Intelligence
# a.  Speech Recognition
# b.  Face Recognition
# c.  Image Style Changes
# d.  Autopilot
# d.  Backpropagation algorithm
# a.  TRUE
# a. Stand-alone mode
# b. Distributed mode
# a.  1
# c.  2
# d.  0.1
# c.  ndim
# b.  HiAI Foundation
# b.  False
# b.  10 with 33
# c.  33 with 10
# c.  GBOT
# a.  Natural language processing
# c.  Computer vision
# d.  Speech Recognition
# a. Open source
# b. Convenience
# c. Mature
# d. Flexible
# d.  The number of rows has no relationship with the number of columns.
# Information only along-pass through
# a.  npu-sim info
# b.  New programming language
# d.  D. E(XY) = E(X)E(Y)
# b. Connectionism
# TRUE
# d.  Null
# GPU
# a.   Financial product recommendation
# b.   Predictive maintenance
# c.   Telecom customer retention
# d.   Retailer grouping
# d.  Parameter
# a.  Adam
# b.  Adagrad
# c.  SGD
# d.  Momentum
# b.  False
# a.  True
# a.  TPU
# b.  GPU
# c.  FPGA
# d.  Large-scale distributed cluster
# Truea.  TensorFlow
# b.  Caffe
# c.  Torch
# d.   Theano
# a.  TRUE
# a.  Calculation chart
# b.  Convolutional Neural Network
# d.  Recurrent neural network
# b.   False
# b. Feature engineering
# a.  True a.  True
# b.  The foothold is reasoning, symbolic reasoning and machine reasoning.
# . Relu function
# c.  Knowledge distillation
# a.  The verification set can coincide with the test set.
# c.  Softmax function
# a.  TRUE  a.  Density clustering
# b.  Hierarchical clustering
# c.  Spectral clustering
# d.  Kmeans
# a.  True
# b.  Mean square loss function
# a.  TRUE
# a. P30
# b. Mate 20
# c.  glory V20
# c. Turing
# a.  Dialogue robot
# b.  EI Basic services
# c.  Natural language processing
# d.  EI Big data service
# a.  Deep feedforward network is a kind of neural network.  c.   Single layer neural networks are also a type of deep learning
# c.  The machine starts to understand and understand, make judgments, and take some
# simple actions
# d. 1956
# a.  Unsupervised algorithm only processes "features" and does not process “tags”
# a. Introduce Keras interface
# c Support more platforms and more languages
# d. Continue to be compatible Tensorflowl.x Related modules
# a.  TRUE
# a.  Quick source code
# b.  Diverse tool chain
# c.  Complete documentation
# d.  plentiful API
# d. There is no inverse matrix for the diagonal matrix.
# d. Jieba
# c.  Fully connected layer
# d.  HiLens
# K-Means
# Hierarchical clustering
# b. FALSE
# Decision tree is a supervised learning
# a.  True
# a.  True  a. Mean variance
# b. Sigmoid cross entropy
# c. Soft max cross entropy
# d. Sparse cross entropy
# e. Weighted Sigmoid Cross Entropy
# a.  Gradient shear
# c.  use Relu Activation function
# d.  Regularization
# b.  Random oversampling
# c.  Synthetic sampling
# d.  Random undersampling
# a. Backpropagation update parameters
# b No relationship
# d.   Independent c.  The discriminator cannot distinguish the true and false samples generated by the
# generator
# a. Single quotes
# b. Double quotes
# c. Three quotes
# a .Automatic parallel
# a. Cross validation
# b. Integration method
# c. Increase regularization
# d. Feature Engineering
# . Explanatory
# c .Object-oriented
# e.  Dynamic data type
# a.  Inline keras
# c.  Avoid overfitting
# a.  El visual cognition  c.  El speech semantics
# d.  El industry scene
# a.  TRUE
# c.  The larger the standard deviation the steeper the normal distribution curve
# a.  The difference between a list and a tuple is that the elements of the tuple cannot be
# duplicate.
# b.  The list uses square brackets and the tuple uses parentheses
# c.  Tuple creation is very simple, just add elements in parentheses and separate them
# with commas
# d.  When a tuple contains only one element, you need to add a comma after the
# element
# c.  Tensor
# b.  Convolutional Neural Network
# c.  Sum
# a.  Adam
# b.   SGD
# c.   Adaboost  d.  Adadelta
# a. TRUE
# a.  TRUE
# b.  False
# b.   FALSE
# b.  FALSE
# a.  True
# b.  BC
# c.  The gradient descent algorithm is fast and reliable  a. sigmoid
# b. tanh
# c. relu
# a. Function
# b. Module
# c. Number
# d. Character string
# d.  Continuous
# a.  DOS
# b. Linux
# c. Mac OS
# d. Windows
# FALSE
# a.  TRUE
# b.  Random gradient descent
# c.  Data cleaning  d. Block chain
# Discrete random variables have no distribution function
# d.  historical data
# c.  Maximum pooling layer
# d.  Average pooling layer
# a.  Beautiful
# c.  Explicit
# d.  Simple
# d. Principal component analysis
# a. TRUE
# a.  Memory door  a. Dark blue
# a.  True
# d.  Integration services
# a.  Probability theory
# c.  KNN
# c.  placeholder
# b.  concat  a.  Tensor
# b.  Variables
# c.  Placeholder
# d. Operation
# e. Conversation
# b.  The number of rows is equal lo the number of columns
# c.  Classification problem
# a.  Data governance
# b.  AI market
# c.  Visual workflow
# d.  Automatic learning
# a.   Model reasoning
# a.  Simple
# b.   Free
# c.   High-level language  d.   Rich library
# a.  Teaching Reproduction Robot
# b.  Robot with sensation
# d.  Intelligent robot
# d. 0
# a.  The program consists of modules
# b.   Module contains statements
# c.   Statement contains an expression
# d.   Expressions create and process objects
# a.   signal
# b.  False
# b.  Calculation Chart
# d.  Tensor
# d.  L0~L5
# a.  Vector calculation unit
# b.  Scalar Computing Unit
# d.  Matrix calculation unit
# d.  Write a file format reader
# a.  rows represents the line information of a text block
# b.  columns represents the column information of a text block
# c.  The incoming image data needs to go through base64 coding
# d.  words represent text block recognition result
# a.  TRUE
# a.  Increase the amount of data
# b.  Feature Engineering
# d.  Add features
# d.  Google
# a.   Data processing tools  a.  True
# a.  Deep learning is a branch of machine learning
# b.   FALSE
# a.   L1 Regularization can do feature selection
# a.  TRUE
# a.  True
# a.  Convolutional neural network
# b.  Recurrent neural network
# a.  Industrial Agent
# b.  Traffic Agent
# c.  Park Agent
# d.  Car intelligence
# c.  4
# d.  2017
# b.  28*28
# d.  Multiple POST queries
# c.  Quickly convert and migrate existing models
# a.  Sigmoid
# b.  ReLU
# c.  Tanh
# a.  Invented in 1989 by the Dutch Guido van Rossum, the first public release was issued
# in 1991.
# b.   Python is purely free software and the source code follows the GPL (GNU General
# Public License) protocol  c.  Python syntax is simple and clean. One of the features is to force blank characters to
# be used as statement indentation
# d.   Python is often nicknamed glue language which can easily connect various modules
# made in other languages
# a.  The entire training set will be trained 5 times
# a.  Intelligent Logistics
# b.  Intelligent Water
# c.   Intelligent transportation
# d.  Intelligent Finance
# e.  Intelligent manufacturing
# a.  result
# a.  Gaussian kernel function
# b.  Polynomial kernel function
# c.  Sigmiod Kernel function
# d.  Linear kernel
# b.   FALSE
# a.  True
# d.  Speech synthesis
# b.   P(XIW) is a conditional probability
# b.  delete
# c.  Xgboost
# d.  The lambda function accepts only one parameter value
# a.  True
# c.   Python modules can define functions classes and variables but the module does not
# contain executable code  c.  GPU
# b.  False
# c.  import
# b.   FALSE
# a.  True
# b.  FALSE
# b.   Reasoning operator
# b.  Perceptual intelligence  b.  Edge computing
# a.   True
# b.  False
# c.   Stochastic gradient algorithm can find the minimum value of the loss function
# a.  Safety
# b.   stable
# c.  real time
# d.  at any time
# a.  TRUE
# a.  Algorithm
# b.  Computing power
# c.  Data
# d.  Scene
# d.  Underfitting
# a.  2
# d.  4
# d.   Shannon
# b.  False
# b.  The larger the value, the smoother the segmentation surface of the classification
# c.  k Value is a hyperparameter
# c.  SAFA
# a.  Text recognition
# b.  Face recognition
# c.  Image recognition
# d.  Content detection
# e.  Image processing
# a.  TRUE
# a.  Machine learning
# b.  Computer vision
# c.  Speech Recognition
# d.   Natural language processing
# a.   FPGA
# b.   CPU
# c.   GPU
# d.   ASIC
# a.  Ascend
# b.  CANN
# c.  ModelArts
# d.  MindSpore
# b.  Atlas 800 model: 3000
# a.   EI Agent
# a.  SGD  c.  Tanh
# d.  Sigmoid
# a.  The function starts with the “def” keyword followed by the function name and
# parentheses.
# b.  The parameters need to be placed in parentheses
# c.  The function content starts with a colon and needs to be indented
# d.   Return the result with return and the function ends.
# a.  Backpropagation can only be used in feedforward neural networks
# c.  Convolutional Neural Network
# a.  True
# a.  Each key and its corresponding value need to be separated by ":”
# b.  Separate the different key-value with “,”
# c.  The entire dictionary is included in the “{}”
# d.  The keys of the dictionary are unique and the data type is uniform
# b.   False
# b.  With the appropriate increasing of the number of hidden layers appropriately, the
# resolution ability of the neural network become stronger
# a.  Data enhancement
# b.  Semantic segmentation
# c.  Information retrieval
# d.  Image generation
# b.  False
# b.  while loop statement
# c.  for loop statement
# d.  Nested loop statement
# a.  TRUE
# a.  True
# a.  As the number of hidden layers of the neural network increases, the classification
# ability of the model gradually weakens  a.   Atlas Driver Installation is carried out
# c.  Cmake Compilation tool is installed
# d.  Environment configuration is completed
# b.   Mean square error loss function
# c.   Cross entropy error loss function
# b.  Xgboost
# b.   FALSE
# c.   Principal component analysis
# c.   Android Studio
# a.  True
# a.  True  c.  Represents confidence, range 0-100
# b.   FALSE
# a.  True
# a.   Speech processing
# b.   Voiceprint recognition
# c.  Speech Recognition
# b. False
# a.   Gradient descent
# a.  TRUE
# a.   Sequence related issues
# a.  int (integer type)
# b.  long (long integer type)  c.  float (floating point type)
# d.  complex (complex number type)
# b.  n=p
# b.  LSTM is unable to solve the problem of vanishing gradient
# b.   False
# a. True
# a.  Equality constraints
# b.  Inequality constraints
# c.  Unconstrained conditions
# a.  TRUE
# a.  Multi-core CPU accelerate  b.  False
# a.  DistBelief
# b.  Efficient sharing of massive data
# a. Searched face similarity
# b. Searched faces id
# c. Searched face position
# a.  Wisdom education
# b.  Smart City
# c.  Smart home
# d.  Smart medical
# a.  True
# c.  Hyperparameters cannot be modified
# a.  Crowd statistics program
# b.  Policy query scheme based on knowledge graph
# c.  Vehicle identification scheme
# d.   Intrusion recognition scheme
# b.  Statisticism
# a.  The interface is user-friendly
# b.  Modular and combination
# c.  Easy to expand
# d.   node (Node)
# a.   TRUE
# d.  There will be a problem of attenuation of long-term transmission and memory
# information
# a.  HiAI Engine
# a.  Relu function
# a.   Country_code:  represents the country where the passport was issued  b.   Nationality:  represents the nationality of representative holder
# c.  passport_number: represents passport number
# d.  confidence: Confidence information of related fields. The greater the confidence, the
# higher the reliability of the corresponding field identified this time. In a statistical
# sense, the greater the confidence, the higher the accuracy
# a.  True
# a.  compile
# b.  D(X+Y)=D(X)+D(Y)
# d.  D(XY)=D(X)D(Y)
# d.  The greater the expectation the smaller the variance
# b.  Only one hidden layer
# d.  Number of samples used
# c.  1
# c.  Automatic coding
# b.   False
# b.   Machine learning
# b.  Architecture
# a.   GNN
# c.   RNN
# b.   As the input value of the discriminant model  d.  The service can provide object and scene labels and can also provide more conceptual
# labels.
# c.  Riemann geometry
# a.  TRUE
# a.  Chain rule
# a.  Can be used to process sequence data.
# a.  Auxiliary case diagnosis
# c.  Gene test report generation
# d.  Entity query
# a.  Natural language processing
# b.  Computer Vision
# c.  Machine learning
# d.  Speech recognition
# a.  True
# b.  result
# a.  Assessment
# b.  training
# c.  prediction
# a.   L1 norm, L2 norm
# b.   Dataset enhancement
# c.   Integration method
# d.   Dropout
# d.  Regular expressions can only process string data not numeric data
# a.   True
# c.  Image Identification
# a.  When there is no face set, you need to create a face set first, then add face data, and
# then search  c.   There is a dedicated interface to delete the specified face set
# d.   There is a dedicated interface to delete the face data in a certain face set
# a.  TRUE
# a.  ak
# b.  region
# c.  project_id
# d.   sk
# a.  (AT ) T = A
# b.  (A+ B) T = AT +BT
# c.  (!EA) T = !EAT
# b.  Activation functions are non-linear functions
# c.   Image style migration
# d.  Feature Engineering
# d.   Remake recognition c.   Mean square error
# d.  /v1.0/image/tagging
# a.   numbers
# b.   String
# c.   list
# d.  tuple
# e.  dictionary
# c.  double64
# c.  tf boost
# d.  from time
# c.  Facebook
# b.  Different 310 processor d.   Update weights
# c.  Hyperplane
# a.  Alpha Go
# b.  Self-driving
# c.  Voice input
# d.   Huawei Mate mobile phone
# c.  ^
# c.  gather
# c.    gather
# a.  Index from left to right defaults from 0
# c.  Index from right lo left defaults from -1  a.   accuracy
# c.   loss
# a.   Machine learning
# b.   Deep learning
# c.  Graph engine
# d.  Batch processing
# d.  OpenStack
# b.  False
# Network Agent
# True
# a.   L1 Regularization
# b.   L2 Regularization
# c.   Dropout  a.  Malformed value
# b.  Duplicate value
# c.  Logically wrong value
# d.  Missing value
# d.   Support vector machine
# isinstance
# is_tensor
# True
# Features are interpretable in traditional machine learning, but weak in deep learning
# inheritance
# Heavy load
# Derived
# Multiple inheritance
# VGGNet
# ResNet
# AlexNet
# GoogleNet
# b.  False
# c.  Loop layer
# a.  Pooling operation is realized by scanning window
# b.  The pooling layer can play a role in dimensionality reduction
# c.   Commonly used pooling methods include maximum pooling and average pooling
# d.   The pooled feature image becomes smaller
# c.  The backpropagation phase sends training inputs to the network to obtain an stimuli
# response
# a.  Traditional rule-based methods, in which the rules can be explicitly clarified manually
# b.  Traditional rule-based methods use explicit programming to solve problems
# c.  The mapping relationship of the model in machine learning is automatically learned
# a.  Backpropagation can only be used in feedforward neural networks  a.  True
# a.  The data distribution itself changes over time, requiring continuous re-adaptation of
# the program, such as predicting the trend of merchandise sales
# c.  Task rules will change over time, such as defect detection on the production line
# d.  The rules are very complicated or cannot be described, such as face recognition and
# voice recognition
# False
# 1spci | grep'd100'
# Feature selection
# Feature extraction
# a.  Industry data
# b.  Industry wisdom
# c.  algorithm
# d.  Computing power
# Assign an initial value to iteratively update weight by checking the difference
# between the best value and the initial
# Random gradient descent
# Adadelta
# Adagrad
# momentum
# RMSProp
# Support for the R language but does not support the Python language
# GBDT Algorithm is easier to overfit than random forest
# True
# 0
# FALSE
# a.  TRUE
# a.  True
# a.  True  d.  Marking
# training
# Reasoning

# %% [markdown]
# ## Download the CSV file

# %%
from google.colab import files
response = input("Download results.csv?   (y/n): ")
if (response.lower() == "y"):
  files.download('results.csv')
# Out:
# Download results.csv?   (y/n): y

# %% [markdown]
# ### CSV to Excel

# %%
read_file = pd.read_csv (r'results.csv')
read_file.to_excel (r'quizGlobal.xlsx', index = None, header=True)

# %%
response = input("Download quizGlobal.csv?   (y/n): ")
if (response.lower() == "y"):
  files.download('quizGlobal.xlsx')
# Out:
# Download quizGlobal.csv?   (y/n): y
