# %%
# !pip install PyPDF2
# !pip install gdown

# %%
# !wget https://raw.githubusercontent.com/liang799/MehScrapper/main/questionPool.pdf -O questionPool.pdf
# Out:
# --2022-07-29 07:55:49--  https://raw.githubusercontent.com/liang799/MehScrapper/main/questionPool.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 890809 (870K) [application/octet-stream]
# Saving to: ‘questionPool.pdf’
#
# questionPool.pdf    100%[===================>] 869.93K  --.-KB/s    in 0.05s
#
# 2022-07-29 07:55:49 (18.3 MB/s) - ‘questionPool.pdf’ saved [890809/890809]

# %% [markdown]
# ## PDF to .txt

# %%
from PyPDF2 import PdfReader

reader = PdfReader("questionPool.pdf")

text = ""  
for page in reader.pages:
    text += page.extractText() + "\n"

f = open("demofile2.txt", "w")
f.write(text)
f.close()
# !tail -n 25 demofile2.txt
# Out:
# b. False
#
# 348.  Among the machine learning algorithms, which of the following is not an integrated
# learning strategy?
# a. Boosting
# b. Stacking
# c. Bagging
# d. Marking
#
# 349.  AI Chips used in business applications can be classified as
# a. training
# b. GPU
# c. Model building
# d. Reasoning

# %% [markdown]
# ### Format demofile2.txt

# %%
import re

read = open("demofile2.txt", "r")
result = open("format.txt", "w")

question = ""
hasQuestion = False
for line in read:
  line = line.strip()
  hasDigit = line[:1].isdigit()
  option = re.findall("^[a-f]\. (\w.+)", line)
 
  if hasDigit:
    question = line
    hasQuestion = True
  elif len(line) != 0:
    if not option:
      question += " " + line
    else:
      if hasQuestion:
        result.write("\n" + question + "\n")
        hasQuestion = False
      result.write(line + "\n")

result.close()
read.close()

# !tail format.txt
# Out:
# a. Boosting
# b. Stacking
# c. Bagging
# d. Marking
#
# 349.  AI Chips used in business applications can be classified as
# a. training
# b. GPU
# c. Model building
# d. Reasoning

# %% [markdown]
# ## TXT to CSV

# %% [markdown]
# ### CSV v1

# %%
import re
mcqs = open("demofile2.txt", "r")

csv = open("results.csv", "w")
csv.write("No,Question,Answer1,AnswerCorrect1,Answer2,AnswerCorrect2,Answer3,AnswerCorrect3,Answer4,AnswerCorrect4,Answer5,AnswerCorrect5,Answer6,AnswerCorrect6,Answer7,AnswerCorrect7,Answer8,AnswerCorrect8,Answer9,AnswerCorrect9,Answer10,AnswerCorrect10,Hint,Explanation,Category\n")

string = ""
for line in mcqs:
  line = line.strip()
  hasDigit = line[:1].isdigit()
  option = re.findall("^[a-f]\. (\w.+)", line)

  if hasDigit:
    quesPos = line.find(".")
    string += line[:quesPos] + ","
    string += "\"" + line[quesPos+2:] + "\""
  elif option:
    string += "," + option[0] + ","
  elif len(line) != 0:
    string += "\"" + line + "\""
  else:
    csv.write(string + "\n")
    string = ""

csv.close()

# %%
import pandas as pd

df = pd.read_csv('results.csv')
df
# Out:
#       No                                           Question  \
# 0      1  TensorF low Operations and Computation Graph a...
# 1      2  What are the categories of artificial intellig...
# 2      3  Traffic agent can a chieve ______ hour full ti...
# 3      4  The pe rceptron can be displayed in space as _...
# 4      5  In Random Forest algorithm, what st rategy is ...
# ..   ...                                                ...
# 346  345   CPUs improve AI performance  mainly through i...
# 347  346   The time interv al in the Python language is ...
# 348  347   Self -encoder is an unsupervised learning alg...
# 349  348   Among the machine learning algorithms, which ...
# 350  349   AI Chips used in business applications can be...
#
#                Answer1 AnswerCorrect1           Answer2 AnswerCorrect2  \
# 0                 True            NaN             False            NaN
# 1               Action            NaN        Perception            NaN
# 2                 7X24            NaN              5X24            NaN
# 3                 line            NaN              flat            NaN
# 4    Cumulative system            NaN  Find the average            NaN
# ..                 ...            ...               ...            ...
# 346               TRUE            NaN             FALSE            NaN
# 347               True      b.  False               NaN            NaN
# 348               True            NaN             False            NaN
# 349           Boosting            NaN          Stacking            NaN
# 350           training            NaN               GPU            NaN
#
#             Answer3 AnswerCorrect3            Answer4 AnswerCorrect4  ...  \
# 0               NaN            NaN                NaN            NaN  ...
# 1         Cognition            NaN  None of the above            NaN  ...
# 2              5X12            NaN               7X12            NaN  ...
# 3        hyperplane            NaN              point            NaN  ...
# 4     Voting system            NaN       Find the max            NaN  ...
# ..              ...            ...                ...            ...  ...
# 346             NaN            NaN                NaN            NaN  ...
# 347             NaN            NaN                NaN            NaN  ...
# 348             NaN            NaN                NaN            NaN  ...
# 349         Bagging            NaN            Marking            NaN  ...
# 350  Model building            NaN          Reasoning            NaN  ...
#
#     AnswerCorrect7 Answer8 AnswerCorrect8 Answer9  AnswerCorrect9  Answer10  \
# 0              NaN     NaN            NaN     NaN             NaN       NaN
# 1              NaN     NaN            NaN     NaN             NaN       NaN
# 2              NaN     NaN            NaN     NaN             NaN       NaN
# 3              NaN     NaN            NaN     NaN             NaN       NaN
# 4              NaN     NaN            NaN     NaN             NaN       NaN
# ..             ...     ...            ...     ...             ...       ...
# 346            NaN     NaN            NaN     NaN             NaN       NaN
# 347            NaN     NaN            NaN     NaN             NaN       NaN
# 348            NaN     NaN            NaN     NaN             NaN       NaN
# 349            NaN     NaN            NaN     NaN             NaN       NaN
# 350            NaN     NaN            NaN     NaN             NaN       NaN
#
#      AnswerCorrect10  Hint  Explanation  Category
# 0                NaN   NaN          NaN       NaN
# 1                NaN   NaN          NaN       NaN
# 2                NaN   NaN          NaN       NaN
# 3                NaN   NaN          NaN       NaN
# 4                NaN   NaN          NaN       NaN
# ..               ...   ...          ...       ...
# 346              NaN   NaN          NaN       NaN
# 347              NaN   NaN          NaN       NaN
# 348              NaN   NaN          NaN       NaN
# 349              NaN   NaN          NaN       NaN
# 350              NaN   NaN          NaN       NaN
#
# [351 rows x 25 columns]

# %% [markdown]
# ### CSV V2

# %%
import re
mcqs = open("format.txt", "r")

csv = open("format.csv", "w")
csv.write("No,Question,Answer1,AnswerCorrect1,Answer2,AnswerCorrect2,Answer3,AnswerCorrect3,Answer4,AnswerCorrect4,Answer5,AnswerCorrect5,Answer6,AnswerCorrect6,Answer7,AnswerCorrect7,Answer8,AnswerCorrect8,Answer9,AnswerCorrect9,Answer10,AnswerCorrect10,Hint,Explanation,Category\n")

string = ""
for line in mcqs:
  line = line.strip()
  hasDigit = line[:1].isdigit()
  option = re.findall("^[a-f]\. (\w.+)", line)

  if hasDigit:
    quesPos = line.find(".")
    string += line[:quesPos] + ","
    string += "\"" + line[quesPos+2:] + "\""
  elif option:
    string += "," + option[0] + ","
  else:
    csv.write(string + "\n")
    string = ""

csv.close()

# %%
csv = open("format.csv", "r")
formatted = open("results.csv", "w")

for line in csv:
  if len(line.strip()) != 0:
    formatted.write(line)
  else:
    print("Miss!")
# Out:
# Miss!

# %%
import pandas as pd

df = pd.read_csv('results.csv')
df
# Out:
#       No                                           Question  \
# 0      1  TensorF low Operations and Computation Graph a...
# 1      2  What are the categories of artificial intellig...
# 2      3  Traffic agent can a chieve ______ hour full ti...
# 3      4  The pe rceptron can be displayed in space as _...
# 4      5  In Random Forest algorithm, what st rategy is ...
# ..   ...                                                ...
# 268  303   Which is wrong with the Python module time in...
# 269  304            Which company l aunched Pytorch  first?
# 270  305   What processor is used for  Altas AI  inference?
# 271  306   Which of the following options is not part of...
# 272  307   The fitted surface of linear regression in th...
#
#                           Answer1 AnswerCorrect1                  Answer2  \
# 0                            True            NaN                    False
# 1                          Action            NaN               Perception
# 2                            7X24            NaN                     5X24
# 3                            line            NaN                     flat
# 4               Cumulative system            NaN         Find the average
# ..                            ...            ...                      ...
# 268                   import time            NaN       from time import *
# 269                         Baidu            NaN                   Google
# 270       Different 910 processor            NaN  Different 310 processor
# 271  Building a calculation chart            NaN             Input tensor
# 272                Curved surface            NaN                     Flat
#
#     AnswerCorrect2           Answer3 AnswerCorrect3            Answer4  \
# 0              NaN               NaN            NaN                NaN
# 1              NaN         Cognition            NaN  None of the above
# 2              NaN              5X12            NaN               7X12
# 3              NaN        hyperplane            NaN              point
# 4              NaN     Voting system            NaN       Find the max
# ..             ...               ...            ...                ...
# 268            NaN  import time as t            NaN          from time
# 269            NaN          Facebook            NaN             Huawei
# 270            NaN               NaN            NaN                NaN
# 271            NaN               NaN            NaN                NaN
# 272            NaN        Hyperplane            NaN       Hypersurface
#
#     AnswerCorrect4  ... AnswerCorrect7 Answer8  AnswerCorrect8  Answer9  \
# 0              NaN  ...            NaN     NaN             NaN      NaN
# 1              NaN  ...            NaN     NaN             NaN      NaN
# 2              NaN  ...            NaN     NaN             NaN      NaN
# 3              NaN  ...            NaN     NaN             NaN      NaN
# 4              NaN  ...            NaN     NaN             NaN      NaN
# ..             ...  ...            ...     ...             ...      ...
# 268            NaN  ...            NaN     NaN             NaN      NaN
# 269            NaN  ...            NaN     NaN             NaN      NaN
# 270            NaN  ...            NaN     NaN             NaN      NaN
# 271            NaN  ...            NaN     NaN             NaN      NaN
# 272            NaN  ...            NaN     NaN             NaN      NaN
#
#      AnswerCorrect9  Answer10  AnswerCorrect10  Hint  Explanation  Category
# 0               NaN       NaN              NaN   NaN          NaN       NaN
# 1               NaN       NaN              NaN   NaN          NaN       NaN
# 2               NaN       NaN              NaN   NaN          NaN       NaN
# 3               NaN       NaN              NaN   NaN          NaN       NaN
# 4               NaN       NaN              NaN   NaN          NaN       NaN
# ..              ...       ...              ...   ...          ...       ...
# 268             NaN       NaN              NaN   NaN          NaN       NaN
# 269             NaN       NaN              NaN   NaN          NaN       NaN
# 270             NaN       NaN              NaN   NaN          NaN       NaN
# 271             NaN       NaN              NaN   NaN          NaN       NaN
# 272             NaN       NaN              NaN   NaN          NaN       NaN
#
# [273 rows x 25 columns]

# %% [markdown]
# ## Download the CSV file

# %%
from google.colab import files
response = input("Download results.csv?   (y/n): ")
if (response.lower() == "y"):
  files.download('results.csv')
# Out:
# Download results.csv?   (y/n): y

# %% [markdown]
# ### CSV to Excel

# %%
read_file = pd.read_csv (r'results.csv')
read_file.to_excel (r'quizGlobal.xlsx', index = None, header=True)

# %%
response = input("Download quizGlobal.csv?   (y/n): ")
if (response.lower() == "y"):
  files.download('quizGlobal.xlsx')
# Out:
# Download quizGlobal.csv?   (y/n): y
